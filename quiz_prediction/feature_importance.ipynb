# %%
import sys, os
DMOL_DIR = "/Users/Henryye/research/shaf/DMOL"
sys.path.append(os.path.join(DMOL_DIR, "utils"))
from ml_utils import *

import numpy as np
import pandas as pd
import math
pd.options.display.max_columns = 999
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression, Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.decomposition import PCA, KernelPCA
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from astropy.stats import median_absolute_deviation
from sklearn.pipeline import Pipeline

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("../data/class_data.csv")
df_proc = preprocess_df(df, verbose = False)

# %%
NEW_VAR_MAP.keys()
# Out:
# dict_keys(['week_1', 'week_2', 'week_3', 'week_4', 'week_5', 'post'])

# %%
def get_metrics(y_true, y_pred, k):
    print("MSE:  {}".format(mean_squared_error(y_true, y_pred)))
    print("MAE:  {}".format(mean_absolute_error(y_true, y_pred)))
    R = r2_score(y_true, y_pred)
    n = len(y_true)
    adjR = 1 - (1-R**2)*(n-1) / (n-k-1)
    print("r-squared:  {}".format(R))
    print("Adjusted r-squared:  {}".format(adjR))

def mad_remove_outlier(df):
    for i, c in enumerate(list(df.columns)):
        mad, mu = median_absolute_deviation(df[c]), df[c].mean()
        for idx in df.index:
            if df.loc[idx, c] > mu + 3 * mad:
                df.loc[idx, c] = mu + 3 * mad
            elif df.loc[idx, c] < mu - 3 * mad:
                df.loc[idx, c] = mu - 3 * mad
    return df
        
    
def group_construct_var(df, var_map_curr, n_comp = None, verbose = False):
    X = pd.DataFrame()
    pca = KernelPCA(n_components=n_comp, kernel="poly", degree=3) if n_comp is not None else None
    for construct in var_map_curr["Quant"]:
        temp = df[var_map_curr["Quant"][construct]].copy()
        temp = temp.fillna(temp.median())  # use median to fillna
        temp = mad_remove_outlier(temp)    # use mad to remove outliers
        if n_comp is None:
            temp_mean = pd.DataFrame(temp.mean(axis=1))
            temp_mean.columns = ["{}_mean".format(construct)]
            X = pd.concat([X, temp_mean], axis = 1)
        else:
            if len(var_map_curr["Quant"][construct]) < n_comp:
                X = pd.concat([X, temp.copy()], axis = 1)
            else:
                temp_pca = pd.DataFrame(pca.fit_transform(temp))
                temp_pca.columns = ["{}_PC{}".format(construct, i) for i in range(1, n_comp+1)]
                X = pd.concat([X, temp_pca], axis = 1)
                assert(temp_pca.shape[1] == 1)
    return X

def construct_X_y(df, week_num, n_comp, verbose):
    var_map_curr = NEW_VAR_MAP["post"] \
                   if week_num == "post" else NEW_VAR_MAP["week_{}".format(week_num)] 
    X = group_construct_var(df, var_map_curr, n_comp, verbose)
    y = df["gr_revqf"] if week_num == "post" else df["gr_revq{}".format(week_num)]
    y = y.fillna(y.median())
    week_num = 6 if week_num == "post" else week_num
    for gr in ["gr_revq{}".format(i) for i in range(1, week_num)]:
        X[gr] = df[gr]
    return X, y
    
def train_model(df, week_num, n_comp = None, use_fr = False, plot = False, verbose = False):
    X, y = construct_X_y(df, week_num, n_comp, verbose)

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.15, random_state = 42)

    reg =  Pipeline([("min_max_scaler", MinMaxScaler()), 
                     ('reg', RandomForestRegressor(random_state = 42, n_jobs = 8))])
    
    param_grid = [{'reg__criterion': ['mse', 'mae'], 'reg__n_estimators': [50, 100, 150, 200, 300],
                   'reg__max_depth': [5, 10, 15, 20, 50, 80, 120]}] 
#     param_grid = [{'reg__criterion': ['mse', 'mae'], 'reg__n_estimators': [10, 15],
#                'reg__max_depth': [5, 10]}] 
    model = GridSearchCV(reg, param_grid, cv = 5, scoring = "neg_mean_squared_error")
    model.fit(X_train, y_train)
    
    print("Found Best Params:  {}".format(model.best_params_))
    print("Training Score with Best Params:  ")
    get_metrics(model.predict(X_train), y_train, X_train.shape[1]); print()
    print("Testing Score with Best Params:  ")
    get_metrics(model.predict(X_test), y_test, X_test.shape[1]); print('\n')
    print()
    return model, X_train, X_test, y_train, y_test
    

def feature_importance_map(df_feature_master, week_num, model, X_train):
    df_feature_imp = pd.DataFrame(model.best_estimator_.named_steps['reg'].feature_importances_, 
                                  index=  X_train.columns, columns = ["week_{}".format(week_num)])
    df_feature_master = pd.concat([df_feature_master, df_feature_imp], axis=1)
    return df_feature_master

# %%
df_feature_master = pd.DataFrame()
for week_num in [i for i in range(1, 6)] + ["post"]:
    print("Week Num:  {}".format(week_num))
    model, X_train, X_test, y_train, y_test = train_model(df_proc, week_num, 1)
    df_feature_master = feature_importance_map(df_feature_master, week_num, model, X_train)
# Out:
# Week Num:  1
# Found Best Params:  {'reg__criterion': 'mae', 'reg__max_depth': 5, 'reg__n_estimators': 300}
# Training Score with Best Params:
# MSE:  9.609982936507937
# MAE:  2.354087301587301
# r-squared:  0.10381456781992349
# Adjusted r-squared:  -0.3242817814063561
#
# Testing Score with Best Params:
# MSE:  20.53975944444444
# MAE:  3.613666666666666
# r-squared:  -2.677430228766848
# Adjusted r-squared:  -11.33726525982899
#
#
#
# Week Num:  2
# Found Best Params:  {'reg__criterion': 'mse', 'reg__max_depth': 10, 'reg__n_estimators': 50}
# Training Score with Best Params:
# MSE:  3.9161105614892002
# MAE:  1.328679993030926
# r-squared:  0.8251213053399991
# Adjusted r-squared:  0.604604313248607
#
# Testing Score with Best Params:
# MSE:  45.05632673937306
# MAE:  4.277910144604491
# r-squared:  -18.863418501958765
# Adjusted r-squared:  -2482.7999030602823
#
#
#
# Week Num:  3
# Found Best Params:  {'reg__criterion': 'mae', 'reg__max_depth': 5, 'reg__n_estimators': 300}
# Training Score with Best Params:
# MSE:  4.371741798941798
# MAE:  1.5269444444444442
# r-squared:  0.8283622278421838
# Adjusted r-squared:  0.6112428415343327
#
# Testing Score with Best Params:
# MSE:  41.792545555555556
# MAE:  4.242666666666667
# r-squared:  -1.0822253599324525
# Adjusted r-squared:  -0.19848210776648445
#
#
#
# Week Num:  4
# Found Best Params:  {'reg__criterion': 'mae', 'reg__max_depth': 5, 'reg__n_estimators': 300}
# Training Score with Best Params:
# MSE:  4.3595368716931215
# MAE:  1.3829960317460315
# r-squared:  0.842252311330646
# Adjusted r-squared:  0.6231138022370419
#
# Testing Score with Best Params:
# MSE:  42.946118518518524
# MAE:  4.486888888888889
# r-squared:  -2.2809042169273868
# Adjusted r-squared:  -10.767067331031978
#
#
#
# Week Num:  5
# Found Best Params:  {'reg__criterion': 'mae', 'reg__max_depth': 5, 'reg__n_estimators': 100}
# Training Score with Best Params:
# MSE:  4.7082797619047625
# MAE:  1.2446428571428574
# r-squared:  0.8552183182315478
# Adjusted r-squared:  0.6516572634784399
#
# Testing Score with Best Params:
# MSE:  58.156033333333326
# MAE:  5.066
# r-squared:  -2.895254359954983
# Adjusted r-squared:  -19.670993864747352
#
#
#
# Week Num:  post
# Found Best Params:  {'reg__criterion': 'mae', 'reg__max_depth': 15, 'reg__n_estimators': 200}
# Training Score with Best Params:
# MSE:  18.708176153273808
# MAE:  2.0264880952380953
# r-squared:  0.8229979550768923
# Adjusted r-squared:  0.5301408355621398
#
# Testing Score with Best Params:
# MSE:  50.57484895833333
# MAE:  5.296666666666667
# r-squared:  -0.012333792557843948
# Adjusted r-squared:  2.1664891904879964

# %%
df_feature_master
# Out:
#                                                 week_1    week_2    week_3  \
# Achievement Goals (Mastery approach)_PC1      0.027512       NaN       NaN
# Achievement Goals (Mastery avoid)_PC1         0.035068       NaN       NaN
# Achievement Goals (Performance approach)_PC1  0.051002       NaN       NaN
# Achievement Goals (Performance avoid)_PC1     0.069101       NaN       NaN
# Achievement Goals (Work avoidance)_PC1        0.021236       NaN       NaN
# Activities_PC1                                     NaN       NaN       NaN
# Attainment Value_PC1                          0.151428  0.023718  0.011756
# Cost Value (Emotional)_PC1                    0.097976  0.029014  0.031218
# Cost Value (Loss of Valued Alternatives)_PC1  0.030014  0.024403  0.020959
# Cost Value (Outside Effort)_PC1               0.092810  0.019080  0.067056
# Course Plan_PC1                               0.022229       NaN       NaN
# Effort Regulation_PC1                         0.044112       NaN       NaN
# Goal Setting Helpful_PC1                           NaN       NaN       NaN
# Grade Expectations - Course_PC1                    NaN  0.058516  0.027278
# Grade Expectations - Final_PC1                     NaN       NaN       NaN
# Grade Expectations - Midterm_PC1                   NaN  0.053301       NaN
# Grade Expectations - Quiz_PC1                      NaN  0.040112  0.065041
# Grade Expectations_PC1                             NaN       NaN       NaN
# Interest Value_PC1                            0.035807  0.012500  0.012641
# Internal/External Motivation_PC1              0.042976  0.008357  0.032401
# Online Expectations_PC1                       0.024021       NaN       NaN
# Online Self Regulation_PC1                    0.095545       NaN       NaN
# Other Activities Rank_PC1                     0.006128  0.100183  0.004145
# Other Activities Time_PC1                     0.031878  0.011912  0.035941
# Persistence_PC1                               0.000000       NaN       NaN
# Plan for Completion_PC1                            NaN  0.013833  0.053372
# Qualtrics Embedded Data_PC1                   0.031171       NaN       NaN
# Reflected Other Activities Time_PC1                NaN       NaN       NaN
# Regret for Activity_PC1                            NaN  0.092720  0.000000
# Satisfaction for Activity_PC1                      NaN  0.072494  0.002837
# Self-Efficacy_PC1                             0.030539       NaN       NaN
# Utility Value_PC1                             0.059446  0.037834  0.021304
# gr_revq1                                           NaN  0.402022  0.199905
# gr_revq2                                           NaN       NaN  0.414147
# gr_revq3                                           NaN       NaN       NaN
# gr_revq4                                           NaN       NaN       NaN
# gr_revq5                                           NaN       NaN       NaN
#
#                                                 week_4    week_5  week_post
# Achievement Goals (Mastery approach)_PC1           NaN       NaN   0.012684
# Achievement Goals (Mastery avoid)_PC1              NaN       NaN   0.009725
# Achievement Goals (Performance approach)_PC1       NaN       NaN   0.021273
# Achievement Goals (Performance avoid)_PC1          NaN       NaN   0.026831
# Achievement Goals (Work avoidance)_PC1             NaN       NaN        NaN
# Activities_PC1                                     NaN       NaN   0.053612
# Attainment Value_PC1                          0.008653  0.012776   0.011537
# Cost Value (Emotional)_PC1                    0.018844  0.006364   0.012127
# Cost Value (Loss of Valued Alternatives)_PC1  0.015276  0.004441   0.016885
# Cost Value (Outside Effort)_PC1               0.012465  0.022100   0.017596
# Course Plan_PC1                                    NaN       NaN   0.016004
# Effort Regulation_PC1                              NaN       NaN   0.016531
# Goal Setting Helpful_PC1                           NaN       NaN   0.015797
# Grade Expectations - Course_PC1               0.037757  0.069380        NaN
# Grade Expectations - Final_PC1                0.039276  0.022360        NaN
# Grade Expectations - Midterm_PC1                   NaN       NaN        NaN
# Grade Expectations - Quiz_PC1                 0.069535  0.007885        NaN
# Grade Expectations_PC1                             NaN       NaN   0.045541
# Interest Value_PC1                            0.015545  0.011664   0.013160
# Internal/External Motivation_PC1              0.014166  0.012936   0.016330
# Online Expectations_PC1                            NaN       NaN        NaN
# Online Self Regulation_PC1                         NaN       NaN   0.014789
# Other Activities Rank_PC1                     0.000000  0.000000   0.016985
# Other Activities Time_PC1                     0.007367  0.020441   0.008375
# Persistence_PC1                                    NaN       NaN        NaN
# Plan for Completion_PC1                       0.005641  0.033280        NaN
# Qualtrics Embedded Data_PC1                        NaN       NaN   0.029585
# Reflected Other Activities Time_PC1           0.022937       NaN        NaN
# Regret for Activity_PC1                       0.066791  0.030549        NaN
# Satisfaction for Activity_PC1                 0.015929  0.004920        NaN
# Self-Efficacy_PC1                                  NaN       NaN   0.029994
# Utility Value_PC1                             0.011159  0.014897   0.014744
# gr_revq1                                      0.034778  0.022518   0.092408
# gr_revq2                                      0.069650  0.069208   0.075845
# gr_revq3                                      0.534232  0.528243   0.192593
# gr_revq4                                           NaN  0.106038   0.135773
# gr_revq5                                           NaN       NaN   0.083278

# %%
print("Top 5 important features")
for c in df_feature_master.columns:
    print("{}: \n{}\n\n".format(c, df_feature_master[c].nlargest(5)))
# Out:
# Top 5 important features
# week_1:
# Attainment Value_PC1                         0.151428
# Cost Value (Emotional)_PC1                   0.097976
# Online Self Regulation_PC1                   0.095545
# Cost Value (Outside Effort)_PC1              0.092810
# Achievement Goals (Performance avoid)_PC1    0.069101
# Name: week_1, dtype: float64
#
#
# week_2:
# gr_revq1                           0.402022
# Other Activities Rank_PC1          0.100183
# Regret for Activity_PC1            0.092720
# Satisfaction for Activity_PC1      0.072494
# Grade Expectations - Course_PC1    0.058516
# Name: week_2, dtype: float64
#
#
# week_3:
# gr_revq2                           0.414147
# gr_revq1                           0.199905
# Cost Value (Outside Effort)_PC1    0.067056
# Grade Expectations - Quiz_PC1      0.065041
# Plan for Completion_PC1            0.053372
# Name: week_3, dtype: float64
#
#
# week_4:
# gr_revq3                          0.534232
# gr_revq2                          0.069650
# Grade Expectations - Quiz_PC1     0.069535
# Regret for Activity_PC1           0.066791
# Grade Expectations - Final_PC1    0.039276
# Name: week_4, dtype: float64
#
#
# week_5:
# gr_revq3                           0.528243
# gr_revq4                           0.106038
# Grade Expectations - Course_PC1    0.069380
# gr_revq2                           0.069208
# Plan for Completion_PC1            0.033280
# Name: week_5, dtype: float64
#
#
# week_post:
# gr_revq3    0.192593
# gr_revq4    0.135773
# gr_revq1    0.092408
# gr_revq5    0.083278
# gr_revq2    0.075845
# Name: week_post, dtype: float64

# %%
print("Pre and Post Comp:  ")
df_feature_master[["week_1", "week_post"]].dropna(how="all")
# Out:
# Pre and Post Comp:
#                                                 week_1  week_post
# Achievement Goals (Mastery approach)_PC1      0.027512   0.012684
# Achievement Goals (Mastery avoid)_PC1         0.035068   0.009725
# Achievement Goals (Performance approach)_PC1  0.051002   0.021273
# Achievement Goals (Performance avoid)_PC1     0.069101   0.026831
# Achievement Goals (Work avoidance)_PC1        0.021236        NaN
# Activities_PC1                                     NaN   0.053612
# Attainment Value_PC1                          0.151428   0.011537
# Cost Value (Emotional)_PC1                    0.097976   0.012127
# Cost Value (Loss of Valued Alternatives)_PC1  0.030014   0.016885
# Cost Value (Outside Effort)_PC1               0.092810   0.017596
# Course Plan_PC1                               0.022229   0.016004
# Effort Regulation_PC1                         0.044112   0.016531
# Goal Setting Helpful_PC1                           NaN   0.015797
# Grade Expectations_PC1                             NaN   0.045541
# Interest Value_PC1                            0.035807   0.013160
# Internal/External Motivation_PC1              0.042976   0.016330
# Online Expectations_PC1                       0.024021        NaN
# Online Self Regulation_PC1                    0.095545   0.014789
# Other Activities Rank_PC1                     0.006128   0.016985
# Other Activities Time_PC1                     0.031878   0.008375
# Persistence_PC1                               0.000000        NaN
# Qualtrics Embedded Data_PC1                   0.031171   0.029585
# Self-Efficacy_PC1                             0.030539   0.029994
# Utility Value_PC1                             0.059446   0.014744
# gr_revq1                                           NaN   0.092408
# gr_revq2                                           NaN   0.075845
# gr_revq3                                           NaN   0.192593
# gr_revq4                                           NaN   0.135773
# gr_revq5                                           NaN   0.083278

# %%
print("Weekly Comp:  ")
df_feature_master[["week_{}".format(i) for i in range(2, 6)]].dropna(how="all")
# Out:
# Weekly Comp:
#                                                 week_2    week_3    week_4  \
# Attainment Value_PC1                          0.023718  0.011756  0.008653
# Cost Value (Emotional)_PC1                    0.029014  0.031218  0.018844
# Cost Value (Loss of Valued Alternatives)_PC1  0.024403  0.020959  0.015276
# Cost Value (Outside Effort)_PC1               0.019080  0.067056  0.012465
# Grade Expectations - Course_PC1               0.058516  0.027278  0.037757
# Grade Expectations - Final_PC1                     NaN       NaN  0.039276
# Grade Expectations - Midterm_PC1              0.053301       NaN       NaN
# Grade Expectations - Quiz_PC1                 0.040112  0.065041  0.069535
# Interest Value_PC1                            0.012500  0.012641  0.015545
# Internal/External Motivation_PC1              0.008357  0.032401  0.014166
# Other Activities Rank_PC1                     0.100183  0.004145  0.000000
# Other Activities Time_PC1                     0.011912  0.035941  0.007367
# Plan for Completion_PC1                       0.013833  0.053372  0.005641
# Reflected Other Activities Time_PC1                NaN       NaN  0.022937
# Regret for Activity_PC1                       0.092720  0.000000  0.066791
# Satisfaction for Activity_PC1                 0.072494  0.002837  0.015929
# Utility Value_PC1                             0.037834  0.021304  0.011159
# gr_revq1                                      0.402022  0.199905  0.034778
# gr_revq2                                           NaN  0.414147  0.069650
# gr_revq3                                           NaN       NaN  0.534232
# gr_revq4                                           NaN       NaN       NaN
#
#                                                 week_5
# Attainment Value_PC1                          0.012776
# Cost Value (Emotional)_PC1                    0.006364
# Cost Value (Loss of Valued Alternatives)_PC1  0.004441
# Cost Value (Outside Effort)_PC1               0.022100
# Grade Expectations - Course_PC1               0.069380
# Grade Expectations - Final_PC1                0.022360
# Grade Expectations - Midterm_PC1                   NaN
# Grade Expectations - Quiz_PC1                 0.007885
# Interest Value_PC1                            0.011664
# Internal/External Motivation_PC1              0.012936
# Other Activities Rank_PC1                     0.000000
# Other Activities Time_PC1                     0.020441
# Plan for Completion_PC1                       0.033280
# Reflected Other Activities Time_PC1                NaN
# Regret for Activity_PC1                       0.030549
# Satisfaction for Activity_PC1                 0.004920
# Utility Value_PC1                             0.014897
# gr_revq1                                      0.022518
# gr_revq2                                      0.069208
# gr_revq3                                      0.528243
# gr_revq4                                      0.106038

# %% [markdown]
# ### Without previous grade

# %%
def construct_X_y(df, week_num, n_comp, verbose):
    var_map_curr = NEW_VAR_MAP["post"] \
                   if week_num == "post" else NEW_VAR_MAP["week_{}".format(week_num)] 
    X = group_construct_var(df, var_map_curr, n_comp, verbose)
    y = df["gr_revqf"] if week_num == "post" else df["gr_revq{}".format(week_num)]
    y = y.fillna(y.median())
    return X, y

# %%
df_feature_master_wo_quiz = pd.DataFrame()
for week_num in [i for i in range(1, 6)] + ["post"]:
    print("Week Num:  {}".format(week_num))
    model, X_train, X_test, y_train, y_test = train_model(df_proc, week_num, 1)
    df_feature_master_wo_quiz = feature_importance_map(df_feature_master_wo_quiz, week_num, model, X_train)
# Out:
# Week Num:  1
# Found Best Params:  {'reg__criterion': 'mae', 'reg__max_depth': 5, 'reg__n_estimators': 300}
# Training Score with Best Params:
# MSE:  9.609982936507937
# MAE:  2.354087301587301
# r-squared:  0.10381456781992349
# Adjusted r-squared:  -0.3242817814063561
#
# Testing Score with Best Params:
# MSE:  20.53975944444444
# MAE:  3.613666666666666
# r-squared:  -2.677430228766848
# Adjusted r-squared:  -11.33726525982899
#
#
#
# Week Num:  2
# Found Best Params:  {'reg__criterion': 'mse', 'reg__max_depth': 5, 'reg__n_estimators': 200}
# Training Score with Best Params:
# MSE:  9.61659692823134
# MAE:  2.3561978257364644
# r-squared:  0.15231443382569443
# Adjusted r-squared:  -0.1922709705825547
#
# Testing Score with Best Params:
# MSE:  29.97076438659404
# MAE:  4.080214405036676
# r-squared:  -4.343130728086491
# Adjusted r-squared:  -249.0789832974873
#
#
#
# Week Num:  3
# Found Best Params:  {'reg__criterion': 'mae', 'reg__max_depth': 5, 'reg__n_estimators': 300}
# Training Score with Best Params:
# MSE:  19.670360119047622
# MAE:  2.6594047619047623
# r-squared:  -2.608317867585943
# Adjusted r-squared:  7.980807741515228
#
# Testing Score with Best Params:
# MSE:  16.19524277777778
# MAE:  3.199222222222222
# r-squared:  -1.9015089292397178
# Adjusted r-squared:  inf
#
#
#
# Week Num:  4
# Found Best Params:  {'reg__criterion': 'mse', 'reg__max_depth': 5, 'reg__n_estimators': 50}
# Training Score with Best Params:
# MSE:  11.985790536274738
# MAE:  2.339241000343854
# r-squared:  0.16952342630681827
# Adjusted r-squared:  -0.2032049262456017
#
# Testing Score with Best Params:
# MSE:  39.131537787148126
# MAE:  4.248098108765821
# r-squared:  -2.714595924063135
# Adjusted r-squared:  -43.5832172165813
#
#
#
# Week Num:  5
# Found Best Params:  {'reg__criterion': 'mse', 'reg__max_depth': 5, 'reg__n_estimators': 50}
# Training Score with Best Params:
# MSE:  21.24034286808025
# MAE:  3.196157167349261
# r-squared:  -1.0399348424481105
# Adjusted r-squared:  1.0994345816561595
#
# Testing Score with Best Params:
# MSE:  49.776661183162815
# MAE:  5.419566036787216
# r-squared:  -7.990438686963749
# Adjusted r-squared:  -878.8595457417775
#
#
#
# Week Num:  post
# Found Best Params:  {'reg__criterion': 'mae', 'reg__max_depth': 5, 'reg__n_estimators': 50}
# Training Score with Best Params:
# MSE:  105.95757254464289
# MAE:  4.816220238095238
# r-squared:  -1.2839195318570504
# Adjusted r-squared:  1.868085439283456
#
# Testing Score with Best Params:
# MSE:  105.3194479166667
# MAE:  8.065833333333336
# r-squared:  -2.3375590520822036
# Adjusted r-squared:  -7.928364643942901

# %%
df_feature_master_wo_quiz
# Out:
#                                                 week_1    week_2    week_3  \
# Achievement Goals (Mastery approach)_PC1      0.027512       NaN       NaN
# Achievement Goals (Mastery avoid)_PC1         0.035068       NaN       NaN
# Achievement Goals (Performance approach)_PC1  0.051002       NaN       NaN
# Achievement Goals (Performance avoid)_PC1     0.069101       NaN       NaN
# Achievement Goals (Work avoidance)_PC1        0.021236       NaN       NaN
# Activities_PC1                                     NaN       NaN       NaN
# Attainment Value_PC1                          0.151428  0.044239  0.073406
# Cost Value (Emotional)_PC1                    0.097976  0.028514  0.076947
# Cost Value (Loss of Valued Alternatives)_PC1  0.030014  0.023472  0.049899
# Cost Value (Outside Effort)_PC1               0.092810  0.083099  0.137246
# Course Plan_PC1                               0.022229       NaN       NaN
# Effort Regulation_PC1                         0.044112       NaN       NaN
# Goal Setting Helpful_PC1                           NaN       NaN       NaN
# Grade Expectations - Course_PC1                    NaN  0.097622  0.051075
# Grade Expectations - Final_PC1                     NaN       NaN       NaN
# Grade Expectations - Midterm_PC1                   NaN  0.080721       NaN
# Grade Expectations - Quiz_PC1                      NaN  0.057285  0.149661
# Grade Expectations_PC1                             NaN       NaN       NaN
# Interest Value_PC1                            0.035807  0.018647  0.032658
# Internal/External Motivation_PC1              0.042976  0.034667  0.102078
# Online Expectations_PC1                       0.024021       NaN       NaN
# Online Self Regulation_PC1                    0.095545       NaN       NaN
# Other Activities Rank_PC1                     0.006128  0.278860  0.009014
# Other Activities Time_PC1                     0.031878  0.067165  0.064925
# Persistence_PC1                               0.000000       NaN       NaN
# Plan for Completion_PC1                            NaN  0.029087  0.182521
# Qualtrics Embedded Data_PC1                   0.031171       NaN       NaN
# Reflected Other Activities Time_PC1                NaN       NaN       NaN
# Regret for Activity_PC1                            NaN  0.059756  0.000000
# Satisfaction for Activity_PC1                      NaN  0.055919  0.009546
# Self-Efficacy_PC1                             0.030539       NaN       NaN
# Utility Value_PC1                             0.059446  0.040947  0.057691
#
#                                                 week_4    week_5  week_post
# Achievement Goals (Mastery approach)_PC1           NaN       NaN   0.015243
# Achievement Goals (Mastery avoid)_PC1              NaN       NaN   0.032683
# Achievement Goals (Performance approach)_PC1       NaN       NaN   0.033877
# Achievement Goals (Performance avoid)_PC1          NaN       NaN   0.061544
# Achievement Goals (Work avoidance)_PC1             NaN       NaN        NaN
# Activities_PC1                                     NaN       NaN   0.127069
# Attainment Value_PC1                          0.017708  0.026699   0.032519
# Cost Value (Emotional)_PC1                    0.017829  0.053659   0.024176
# Cost Value (Loss of Valued Alternatives)_PC1  0.042226  0.045689   0.021690
# Cost Value (Outside Effort)_PC1               0.051306  0.037320   0.036599
# Course Plan_PC1                                    NaN       NaN   0.021474
# Effort Regulation_PC1                              NaN       NaN   0.086168
# Goal Setting Helpful_PC1                           NaN       NaN   0.024857
# Grade Expectations - Course_PC1               0.048219  0.248675        NaN
# Grade Expectations - Final_PC1                0.245333  0.086176        NaN
# Grade Expectations - Midterm_PC1                   NaN       NaN        NaN
# Grade Expectations - Quiz_PC1                 0.030624  0.032268        NaN
# Grade Expectations_PC1                             NaN       NaN   0.243539
# Interest Value_PC1                            0.035602  0.024573   0.029830
# Internal/External Motivation_PC1              0.010965  0.040670   0.036890
# Online Expectations_PC1                            NaN       NaN        NaN
# Online Self Regulation_PC1                         NaN       NaN   0.020340
# Other Activities Rank_PC1                     0.000000  0.000000   0.025101
# Other Activities Time_PC1                     0.011799  0.047220   0.013825
# Persistence_PC1                                    NaN       NaN        NaN
# Plan for Completion_PC1                       0.062998  0.180603        NaN
# Qualtrics Embedded Data_PC1                        NaN       NaN   0.078826
# Reflected Other Activities Time_PC1           0.050956       NaN        NaN
# Regret for Activity_PC1                       0.329668  0.137492        NaN
# Satisfaction for Activity_PC1                 0.015035  0.016112        NaN
# Self-Efficacy_PC1                                  NaN       NaN   0.021104
# Utility Value_PC1                             0.029731  0.022843   0.012647

# %%
print("Top 5 important features")
for c in df_feature_master_wo_quiz.columns:
    print("{}: \n{}\n\n".format(c, df_feature_master_wo_quiz[c].nlargest(5)))
# Out:
# Top 5 important features
# week_1:
# Attainment Value_PC1                         0.151428
# Cost Value (Emotional)_PC1                   0.097976
# Online Self Regulation_PC1                   0.095545
# Cost Value (Outside Effort)_PC1              0.092810
# Achievement Goals (Performance avoid)_PC1    0.069101
# Name: week_1, dtype: float64
#
#
# week_2:
# Other Activities Rank_PC1           0.278860
# Grade Expectations - Course_PC1     0.097622
# Cost Value (Outside Effort)_PC1     0.083099
# Grade Expectations - Midterm_PC1    0.080721
# Other Activities Time_PC1           0.067165
# Name: week_2, dtype: float64
#
#
# week_3:
# Plan for Completion_PC1             0.182521
# Grade Expectations - Quiz_PC1       0.149661
# Cost Value (Outside Effort)_PC1     0.137246
# Internal/External Motivation_PC1    0.102078
# Cost Value (Emotional)_PC1          0.076947
# Name: week_3, dtype: float64
#
#
# week_4:
# Regret for Activity_PC1                0.329668
# Grade Expectations - Final_PC1         0.245333
# Plan for Completion_PC1                0.062998
# Cost Value (Outside Effort)_PC1        0.051306
# Reflected Other Activities Time_PC1    0.050956
# Name: week_4, dtype: float64
#
#
# week_5:
# Grade Expectations - Course_PC1    0.248675
# Plan for Completion_PC1            0.180603
# Regret for Activity_PC1            0.137492
# Grade Expectations - Final_PC1     0.086176
# Cost Value (Emotional)_PC1         0.053659
# Name: week_5, dtype: float64
#
#
# week_post:
# Grade Expectations_PC1                       0.243539
# Activities_PC1                               0.127069
# Effort Regulation_PC1                        0.086168
# Qualtrics Embedded Data_PC1                  0.078826
# Achievement Goals (Performance avoid)_PC1    0.061544
# Name: week_post, dtype: float64
