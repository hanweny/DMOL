# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

import sys, os
DMOL_DIR = "/Users/Henryye/research/shaf/DMOL"
sys.path.append(os.path.join(DMOL_DIR, "utils"))

from ml_utils import *

# %%
df = pd.read_csv("../data/class_data.csv")
df_proc = preprocess_df(df, verbose = False)

# %% [markdown]
# #### Create correlation matrix for each week

# %%
def plot_corr(df, size = (10, 5)):
    corr = df.corr()
    f = plt.figure(figsize=size)
    plt.matshow(corr, fignum=f.number)
    plt.xticks(range(len(corr.columns)), corr.columns, rotation='vertical')
    plt.yticks(range(len(corr.columns)), corr.columns)
    cb = plt.colorbar()
    cb.ax.tick_params(labelsize=12)
    plt.show()
    
for week_num in range(1, 6):
    print("Week", week_num)
    curr_var_map = NEW_VAR_MAP["week_{}".format(week_num)]["Quant"]
    curr_var_list = [j for i in curr_var_map.values() for j in i]
    plot_corr(df_proc[curr_var_list], (19, 15))
# Out:
# Week 1
# Week 2
# Week 3
# Week 4
# Week 5

# %% [markdown]
# #### Create correlation matrix for each week by Construct

# %%
def plot_corr_by_week_construct(week_num):
    week_num = "week_{}".format(week_num)
    print(week_num, '\n')
    for c in NEW_VAR_MAP[week_num]["Quant"]:
        print("Construct {}".format(c))
        print(list(NEW_VAR_MAP[week_num]["Quant"][c]))
        plot_corr(df_proc[list(NEW_VAR_MAP[week_num]["Quant"][c])])

# %%
# Week 1
plot_corr_by_week_construct(1)
# Out:
# week_1
#
# Construct Achievement Goals (Mastery approach)
# ['pre_agqmap2', 'pre_agqmap1']
# Construct Achievement Goals (Mastery avoid)
# ['pre_agqmap5', 'pre_agqmap10']
# Construct Achievement Goals (Performance approach)
# ['pre_agqmap6', 'pre_agqmap17']
# Construct Achievement Goals (Performance avoid)
# ['pre_agqmap16', 'pre_agqmap3', 'pre_agqmap7']
# Construct Achievement Goals (Work avoidance)
# ['pre_agqmap12']
# Construct Attainment Value
# ['pre_att1', 'pre_att3', 'pre_att2']
# Construct Cost Value (Emotional)
# ['pre_cost1', 'pre_cost2', 'pre_cost3']
# Construct Cost Value (Loss of Valued Alternatives)
# ['pre_cost4', 'pre_cost5', 'pre_cost6']
# Construct Cost Value (Outside Effort)
# ['pre_cost7', 'pre_cost9', 'pre_cost8']
# Construct Course Plan
# ['pre_study', 'pre_studydays']
# Construct Effort Regulation
# ['pre_er1', 'pre_er2', 'pre_er8x', 'pre_er4', 'pre_er7x', 'pre_er3']
# Construct Interest Value
# ['pre_int4', 'pre_int3', 'pre_int2', 'pre_int1']
# Construct Internal/External Motivation
# ['pre_iemot3', 'pre_iemot2', 'pre_iemot4', 'pre_iemot1', 'pre_iemot5', 'pre_iemot6', 'pre_iemot7']
# Construct Online Expectations
# ['pre_onlexp1', 'pre_onlexp2']
# Construct Online Self Regulation
# ['pre_olsrl2', 'pre_orsh3', 'pre_orsh2', 'pre_orsh5', 'pre_olsrl5', 'pre_orsh6', 'pre_olsrl3', 'pre_olsrl4', 'pre_orsh4', 'pre_orsh1', 'pre_orsh7', 'pre_olsrl1']
# Construct Other Activities Rank
# ['pre_oact1rank', 'pre_oact3rank', 'pre_courserank', 'pre_oact2rank']
# Construct Other Activities Time
# ['pre_oact1hrs', 'pre_oact3hrs', 'pre_oact2hrs']
# Construct Persistence
# ['pre_persist']
# Construct Qualtrics Embedded Data
# ['pre_finished', 'pre_progress', 'pre_duration', 'pre_longitude', 'pre_latitude']
# Construct Self-Efficacy
# ['pre_se4', 'pre_se3', 'pre_se5', 'pre_se2', 'pre_se1']
# Construct Utility Value
# ['pre_util5', 'pre_util4', 'pre_util3', 'pre_util1', 'pre_util2']

# %%
# week 2
plot_corr_by_week_construct(2)
# Out:
# week_2
#
# Construct Attainment Value
# ['att3w2']
# Construct Cost Value (Emotional)
# ['cost2w2']
# Construct Cost Value (Loss of Valued Alternatives)
# ['cost6w2']
# Construct Cost Value (Outside Effort)
# ['cost9w2']
# Construct Grade Expectations - Course
# ['wgradecw2', 'egradecw2', 'badgradecw2']
# Construct Grade Expectations - Midterm
# ['wgrademw2', 'egrademw2', 'badgrademw2']
# Construct Grade Expectations - Quiz
# ['wgradeqw2', 'egradeqw2', 'badgradeqw2']
# Construct Interest Value
# ['int3w2']
# Construct Internal/External Motivation
# ['iemot2w2', 'iemot3w2', 'iemot4w2', 'iemot1w2', 'iemot7w2', 'iemot5w2']
# Construct Other Activities Rank
# ['woactrank2', 'wcourserank1', 'woactrank1']
# Construct Other Activities Time
# ['woacthrs1', 'woacthrs2', 'wcoursehrs1']
# Construct Plan for Completion
# ['wcourseplan1', 'woactplan1', 'woactplan2']
# Construct Regret for Activity
# ['wcoursereg1', 'woactreg2', 'woactreg1']
# Construct Satisfaction for Activity
# ['wcoursesat1', 'woactsat2', 'woactsat1']
# Construct Utility Value
# ['util4w2', 'util1w2', 'util5w2']

# %%
# Week 3
plot_corr_by_week_construct(3)
# Out:
# week_3
#
# Construct Attainment Value
# ['att3w3']
# Construct Cost Value (Emotional)
# ['cost2w3']
# Construct Cost Value (Loss of Valued Alternatives)
# ['cost6w3']
# Construct Cost Value (Outside Effort)
# ['cost9w3']
# Construct Grade Expectations - Course
# ['egradecw3', 'badgradecw3', 'wgradecw3']
# Construct Grade Expectations - Quiz
# ['wgradeqw3', 'egradeqw3', 'badgradeqw3']
# Construct Interest Value
# ['int3w3']
# Construct Internal/External Motivation
# ['iemot5w3', 'iemot3w3', 'iemot2w3', 'iemot1w3', 'iemot4w3', 'iemot7w3']
# Construct Other Activities Rank
# ['woactrank11', 'woactrank12', 'wcourserank2']
# Construct Other Activities Time
# ['wcoursehrs2', 'woacthrs11', 'woacthrs12']
# Construct Plan for Completion
# ['wcourseplan2', 'woactplan12', 'woactplan11']
# Construct Regret for Activity
# ['wcoursereg2', 'woactreg12', 'woactreg11']
# Construct Satisfaction for Activity
# ['woactsat11', 'wcoursesat2', 'woactsat12']
# Construct Utility Value
# ['util5w3', 'util1w3', 'util4w3']

# %%
# Week 4
plot_corr_by_week_construct(4)
# Out:
# week_4
#
# Construct Attainment Value
# ['att3w4']
# Construct Cost Value (Emotional)
# ['cost2w4']
# Construct Cost Value (Loss of Valued Alternatives)
# ['cost6w4']
# Construct Cost Value (Outside Effort)
# ['cost9w4']
# Construct Grade Expectations - Course
# ['wgradecw4', 'egradecw4', 'badgradecw4']
# Construct Grade Expectations - Final
# ['badgradefw4', 'egradefw4', 'wgradefw4']
# Construct Grade Expectations - Quiz
# ['badgradeqw4', 'egradeqw4', 'wgradeqw4']
# Construct Interest Value
# ['int3w4']
# Construct Internal/External Motivation
# ['iemot1w4', 'iemot4w4', 'iemot3w4', 'iemot5w4', 'iemot7w4', 'iemot2w4']
# Construct Other Activities Rank
# ['wcourserank3', 'woactrank22', 'woactrank21']
# Construct Other Activities Time
# ['woacthrs21', 'wcoursehrs3', 'woacthrs22']
# Construct Plan for Completion
# ['woactplan21', 'woactplan22', 'wcourseplan3']
# Construct Reflected Other Activities Time
# ['wcoursehrsx3']
# Construct Regret for Activity
# ['woactreg21', 'wcoursereg3', 'woactreg22']
# Construct Satisfaction for Activity
# ['wcoursesat3', 'woactsat21', 'woactsat22']
# Construct Utility Value
# ['util5w4', 'util4w4', 'util1w4']

# %%
# Week 5
plot_corr_by_week_construct(5)
# Out:
# week_5
#
# Construct Attainment Value
# ['att3w5']
# Construct Cost Value (Emotional)
# ['cost2w5']
# Construct Cost Value (Loss of Valued Alternatives)
# ['cost6w5']
# Construct Cost Value (Outside Effort)
# ['cost9w5']
# Construct Grade Expectations - Course
# ['badgradecw5', 'egradecw5', 'wgradecw5']
# Construct Grade Expectations - Final
# ['egradefw5', 'wgradefw5', 'badgradefw5']
# Construct Grade Expectations - Quiz
# ['wgradeqw5', 'badgradeqw5', 'egradeqw5']
# Construct Interest Value
# ['int3w5']
# Construct Internal/External Motivation
# ['iemot2w5', 'iemot4w5', 'iemot7w5', 'iemot5w5', 'iemot3w5', 'iemot1w5']
# Construct Other Activities Rank
# ['woactrank32', 'wcourserank4', 'woactrank31']
# Construct Other Activities Time
# ['woacthrs31', 'woacthrs32', 'wcoursehrs4']
# Construct Plan for Completion
# ['wcourseplan4', 'woactplan31', 'woactplan32']
# Construct Regret for Activity
# ['woactreg32', 'wcoursereg4', 'woactreg31']
# Construct Satisfaction for Activity
# ['woactsat32', 'woactsat31', 'wcoursesat4']
# Construct Utility Value
# ['util4w5', 'util1w5', 'util5w5']
