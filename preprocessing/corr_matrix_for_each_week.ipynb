# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

import sys, os
DMOL_DIR = "../"
sys.path.append(os.path.join(DMOL_DIR, "utils"))

from ml_utils import *

# %%
df = pd.read_csv("../data/class_data.csv")
df_proc = preprocess_df(df, verbose = False)

# %% [markdown]
# #### Create correlation matrix for each week

# %%
def plot_corr(df, col_names, size = (10, 5)):
    corr = df.corr()
    f = plt.figure(figsize=size)
    plt.matshow(corr, fignum=f.number)
    plt.xticks(range(len(corr.columns)), col_names, rotation='vertical')
    plt.yticks(range(len(corr.columns)), col_names)
    cb = plt.colorbar()
    plt.clim(-1, 1)
    cb.ax.tick_params(labelsize=12)
    plt.show()
    
for week_num in range(1, 6):
    print("Week", week_num)
    curr_var_map = NEW_VAR_MAP["week_{}".format(week_num)]["Quant"]
    curr_var_list = [[var, "{}_{}".format(constr, var)]  for constr, var_set in curr_var_map.items() for var in list(var_set)]
    plot_corr(df_proc[[i[0] for i in curr_var_list]], [i[1] for i in curr_var_list], (19, 15))
# Out:
# Week 1
# Week 2
# Week 3
# Week 4
# Week 5

# %% [markdown]
# #### Create correlation matrix for each week by Construct

# %%
def plot_corr_by_week_construct(week_num):
    week_num = "week_{}".format(week_num)
    print(week_num, '\n')
    for c in NEW_VAR_MAP[week_num]["Quant"]:
        print("Construct {}".format(c))
        print(list(NEW_VAR_MAP[week_num]["Quant"][c]))
        plot_corr(df_proc[list(NEW_VAR_MAP[week_num]["Quant"][c])])

# %%
# Week 1
plot_corr_by_week_construct(1)
# Out:
# week_1
#
# Construct Achievement Goals (Mastery approach)
# ['pre_agqmap2', 'pre_agqmap1']
# Construct Achievement Goals (Mastery avoid)
# ['pre_agqmap5', 'pre_agqmap10']
# Construct Achievement Goals (Performance approach)
# ['pre_agqmap6', 'pre_agqmap17']
# Construct Achievement Goals (Performance avoid)
# ['pre_agqmap16', 'pre_agqmap3', 'pre_agqmap7']
# Construct Achievement Goals (Work avoidance)
# ['pre_agqmap12']
# Construct Attainment Value
# ['pre_att2', 'pre_att3', 'pre_att1']
# Construct Cost Value (Emotional)
# ['pre_cost1', 'pre_cost3', 'pre_cost2']
# Construct Cost Value (Loss of Valued Alternatives)
# ['pre_cost5', 'pre_cost4', 'pre_cost6']
# Construct Cost Value (Outside Effort)
# ['pre_cost7', 'pre_cost9', 'pre_cost8']
# Construct Course Plan
# ['pre_study', 'pre_studydays']
# Construct Effort Regulation
# ['pre_er2', 'pre_er3', 'pre_er1', 'pre_er7x', 'pre_er4', 'pre_er8x']
# Construct Interest Value
# ['pre_int1', 'pre_int4', 'pre_int2', 'pre_int3']
# ...

# %%
# week 2
plot_corr_by_week_construct(2)
# Out:
# week_2
#
# Construct Attainment Value
# ['att3w2']
# Construct Cost Value (Emotional)
# ['cost2w2']
# Construct Cost Value (Loss of Valued Alternatives)
# ['cost6w2']
# Construct Cost Value (Outside Effort)
# ['cost9w2']
# Construct Grade Expectations - Course
# ['badgradecw2', 'wgradecw2', 'egradecw2']
# Construct Grade Expectations - Midterm
# ['badgrademw2', 'egrademw2', 'wgrademw2']
# Construct Grade Expectations - Quiz
# ['wgradeqw2', 'badgradeqw2', 'egradeqw2']
# Construct Interest Value
# ['int3w2']
# Construct Internal/External Motivation
# ['iemot1w2', 'iemot2w2', 'iemot4w2', 'iemot3w2', 'iemot5w2', 'iemot7w2']
# Construct Other Activities Rank
# ['woactrank2', 'woactrank1', 'wcourserank1']
# Construct Other Activities Time
# ['wcoursehrs1', 'woacthrs1', 'woacthrs2']
# Construct Plan for Completion
# ['woactplan2', 'woactplan1', 'wcourseplan1']
# Construct Regret for Activity
# ['wcoursereg1', 'woactreg2', 'woactreg1']
# Construct Satisfaction for Activity
# ...

# %%
# Week 3
plot_corr_by_week_construct(3)
# Out:
# week_3
#
# Construct Attainment Value
# ['att3w3']
# Construct Cost Value (Emotional)
# ['cost2w3']
# Construct Cost Value (Loss of Valued Alternatives)
# ['cost6w3']
# Construct Cost Value (Outside Effort)
# ['cost9w3']
# Construct Grade Expectations - Course
# ['egradecw3', 'wgradecw3', 'badgradecw3']
# Construct Grade Expectations - Quiz
# ['egradeqw3', 'badgradeqw3', 'wgradeqw3']
# Construct Interest Value
# ['int3w3']
# Construct Internal/External Motivation
# ['iemot1w3', 'iemot2w3', 'iemot3w3', 'iemot7w3', 'iemot4w3', 'iemot5w3']
# Construct Other Activities Rank
# ['woactrank11', 'woactrank12', 'wcourserank2']
# Construct Other Activities Time
# ['woacthrs11', 'wcoursehrs2', 'woacthrs12']
# Construct Plan for Completion
# ['woactplan11', 'wcourseplan2', 'woactplan12']
# Construct Regret for Activity
# ['woactreg12', 'wcoursereg2', 'woactreg11']
# Construct Satisfaction for Activity
# ['wcoursesat2', 'woactsat11', 'woactsat12']
# Construct Utility Value
# ...

# %%
# Week 4
plot_corr_by_week_construct(4)
# Out:
# week_4
#
# Construct Attainment Value
# ['att3w4']
# Construct Cost Value (Emotional)
# ['cost2w4']
# Construct Cost Value (Loss of Valued Alternatives)
# ['cost6w4']
# Construct Cost Value (Outside Effort)
# ['cost9w4']
# Construct Grade Expectations - Course
# ['badgradecw4', 'egradecw4', 'wgradecw4']
# Construct Grade Expectations - Final
# ['wgradefw4', 'badgradefw4', 'egradefw4']
# Construct Grade Expectations - Quiz
# ['wgradeqw4', 'badgradeqw4', 'egradeqw4']
# Construct Interest Value
# ['int3w4']
# Construct Internal/External Motivation
# ['iemot3w4', 'iemot4w4', 'iemot2w4', 'iemot7w4', 'iemot1w4', 'iemot5w4']
# Construct Other Activities Rank
# ['woactrank21', 'woactrank22', 'wcourserank3']
# Construct Other Activities Time
# ['woacthrs21', 'wcoursehrs3', 'woacthrs22']
# Construct Plan for Completion
# ['woactplan22', 'wcourseplan3', 'woactplan21']
# Construct Reflected Other Activities Time
# ['wcoursehrsx3']
# Construct Regret for Activity
# ...

# %%
# Week 5
plot_corr_by_week_construct(5)
# Out:
# week_5
#
# Construct Attainment Value
# ['att3w5']
# Construct Cost Value (Emotional)
# ['cost2w5']
# Construct Cost Value (Loss of Valued Alternatives)
# ['cost6w5']
# Construct Cost Value (Outside Effort)
# ['cost9w5']
# Construct Grade Expectations - Course
# ['wgradecw5', 'badgradecw5', 'egradecw5']
# Construct Grade Expectations - Final
# ['badgradefw5', 'wgradefw5', 'egradefw5']
# Construct Grade Expectations - Quiz
# ['badgradeqw5', 'egradeqw5', 'wgradeqw5']
# Construct Interest Value
# ['int3w5']
# Construct Internal/External Motivation
# ['iemot1w5', 'iemot5w5', 'iemot2w5', 'iemot3w5', 'iemot4w5', 'iemot7w5']
# Construct Other Activities Rank
# ['woactrank32', 'wcourserank4', 'woactrank31']
# Construct Other Activities Time
# ['woacthrs32', 'woacthrs31', 'wcoursehrs4']
# Construct Plan for Completion
# ['woactplan31', 'woactplan32', 'wcourseplan4']
# Construct Regret for Activity
# ['woactreg32', 'woactreg31', 'wcoursereg4']
# Construct Satisfaction for Activity
# ...
